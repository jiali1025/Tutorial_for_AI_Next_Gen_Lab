# %% [markdown]
# Problem statement and visualization data

# %%
from Data.Data import DataGen

datagen = DataGen()
data_train = datagen.system_ODE_1(data_name='reactor_1_train', period=20, seed=29)
data_test = datagen.system_ODE_1(data_name='reactor_1_test', period=10, seed=23)

print(data_train.shape, data_test.shape)
# Out:
# (1000, 7) (500, 7)

# %%
datagen.visualize(data_name='reactor_1_train')
datagen.visualize(data_name='reactor_1_test')
